# %%
import cv2
# py -3.11 -m pip install opencv-python

cv2.__version__
# Out:
# '4.9.0'

# %%
# Image 불러오기
lena_img = cv2.imread("images\lena.jpg")
print(lena_img)
# Out:
# [[[127 136 226]
#   [127 136 226]
#   [127 136 226]
#   ...
#   [122 146 234]
#   [102 127 213]
#   [ 74 100 184]]
#
#  [[128 137 227]
#   [128 137 227]
#   [127 136 226]
#   ...
#   [129 149 237]
#   [113 134 219]
#   [ 87 108 193]]
#
#  [[127 138 228]
#   [127 138 228]
#   [126 137 227]
#   ...
#   [132 146 234]
#   [117 130 216]
#   [ 91 105 188]]
#
#  ...
#
#  [[ 57  19  85]
#   [ 61  23  89]
#   [ 65  27  93]
#   ...
#   [ 78  71 176]
#   [ 77  68 178]
#   [ 73  66 177]]
#
#  [[ 55  17  83]
#   [ 61  23  89]
#   [ 67  29  95]
#   ...
#   [ 81  73 180]
#   [ 79  72 183]
#   [ 78  72 185]]
#
#  [[ 55  17  83]
#   [ 61  23  89]
#   [ 69  31  97]
#   ...
#   [ 78  72 181]
#   [ 79  72 183]
#   [ 78  72 185]]]

# %%
# 흑백 이미지 opencv에서 보이기
type(lena_img)

lena_gray = cv2.imread("images/lena.jpg", cv2.IMREAD_GRAYSCALE)
cv2.imshow("Lena", lena_gray)
cv2.waitKey(1000) #단위 ms
cv2.destroyAllWindows()

# %%
# gray로 파일 저장
lena_gray
if(cv2.imwrite("lena_gray.png", lena_gray)):
    print("write ok")
else:
    print("write error")
# Out:
# write ok

# %%
#이미지 크기 조절
resize = cv2.resize(lena_img, dsize = (1256, 1256), interpolation = cv2.INTER_LINEAR)
cv2.imshow("Lena", resize)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
from matplotlib import pyplot as plt

plt.imshow(lena_img)
plt.show()

# %%
b,g,r = cv2.split(lena_img)
rgb = cv2.merge([r,g,b])
plt.imshow(rgb)
plt.show()

# %%
flags = [flag for flag in dir(cv2) if flag.startswith('COLOR_')]
print(flags)
# Out:
# ['COLOR_BAYER_BG2BGR', 'COLOR_BAYER_BG2BGRA', 'COLOR_BAYER_BG2BGR_EA', 'COLOR_BAYER_BG2BGR_VNG', 'COLOR_BAYER_BG2GRAY', 'COLOR_BAYER_BG2RGB', 'COLOR_BAYER_BG2RGBA', 'COLOR_BAYER_BG2RGB_EA', 'COLOR_BAYER_BG2RGB_VNG', 'COLOR_BAYER_BGGR2BGR', 'COLOR_BAYER_BGGR2BGRA', 'COLOR_BAYER_BGGR2BGR_EA', 'COLOR_BAYER_BGGR2BGR_VNG', 'COLOR_BAYER_BGGR2GRAY', 'COLOR_BAYER_BGGR2RGB', 'COLOR_BAYER_BGGR2RGBA', 'COLOR_BAYER_BGGR2RGB_EA', 'COLOR_BAYER_BGGR2RGB_VNG', 'COLOR_BAYER_GB2BGR', 'COLOR_BAYER_GB2BGRA', 'COLOR_BAYER_GB2BGR_EA', 'COLOR_BAYER_GB2BGR_VNG', 'COLOR_BAYER_GB2GRAY', 'COLOR_BAYER_GB2RGB', 'COLOR_BAYER_GB2RGBA', 'COLOR_BAYER_GB2RGB_EA', 'COLOR_BAYER_GB2RGB_VNG', 'COLOR_BAYER_GBRG2BGR', 'COLOR_BAYER_GBRG2BGRA', 'COLOR_BAYER_GBRG2BGR_EA', 'COLOR_BAYER_GBRG2BGR_VNG', 'COLOR_BAYER_GBRG2GRAY', 'COLOR_BAYER_GBRG2RGB', 'COLOR_BAYER_GBRG2RGBA', 'COLOR_BAYER_GBRG2RGB_EA', 'COLOR_BAYER_GBRG2RGB_VNG', 'COLOR_BAYER_GR2BGR', 'COLOR_BAYER_GR2BGRA', 'COLOR_BAYER_GR2BGR_EA', 'COLOR_BAYER_GR2BGR_VNG', 'COLO
# ...

# %%
#b,g,r
b,g,r = lena_img[0][0]
print('rgb', lena_img[0][0])
print('YPrPb', 0.114 * b + 0.587 * g + 0.299 * r)
print('YCrCb', 0.072 * b + 0.7152 * g + 0.2116 * r)
print(0.114 + 0.587 + 0.299)
# Out:
# rgb [127 136 226]
# YPrPb 161.884
# YCrCb 154.2328
# 1.0

# %%
cap = cv2.VideoCapture("images/Puppies-HD.mp4")

while(cap.isOpened()):
    print(cap.get(cv2.CAP_PROP_FPS))        
    delay = int(80/cap.get(cv2.CAP_PROP_FPS))
    ret, img = cap.read()
    if ret:
        cv2.imshow("Movie", img)
        if cv2.waitKey(delay) & 0xFF == 27:
            break
    else:
        break

cap.release()

cv2.destroyAllWindows()
# Out:
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# 29.97002997002997
# ...

# %%
import time
import cv2

# 내장 카메라를 사용하여 캡처하기 위해 인덱스 0을 지정합니다.
cap = cv2.VideoCapture(0)
width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
print(width)

if(cap.isOpened()):
    print(cap.get(cv2.CAP_PROP_FPS))        
    delay = int(1000/cap.get(cv2.CAP_PROP_FPS)*2)
    while True:
        ret, img = cap.read()
        if ret:
            cv2.imshow("Movie", cv2.cvtColor(img, cv2.COLOR_BGR2GRAY))
            if cv2.waitKey(delay) & 0xFF == 27:
                break

cap.release()
cv2.destroyAllWindows()
# Out:
# 640.0
# 30.0

# %%
# IP CAMERA, 지원할 프로토콜 RTSP()
cap = cv2.VideoCapture("rtsp://uesrid:pass@10.10.23.202:553/profile1")

import time
import cv2

cap = cv2.VideoCapture(0)
width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
print(width)

if(cap.isOpened()):
    cap.get(cv2.CAP_PROP_FPS)
    
    cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
    cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)

    print(cap.get(cv2.CAP_PROP_FPS))
    delay = int((1000/ cap.get(cv2.CAP_PROP_FPS))/2)
    while True:
        ret, img = cap.read()
        if ret:
            cv2.imshow("WebCam", cv2.cvtColor(img, cv2.COLOR_BGR2GRAY))
            if cv2.waitKey(delay) == ord('esc'):    
                break


cap.release()
cv2.destroyAllWindows()
# Out:
# 640.0
# 30.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 23
#      21         if ret:
#      22             cv2.imshow("WebCam", cv2.cvtColor(img, cv2.COLOR_BGR2GRAY))
# ---> 23             if cv2.waitKey(delay) == ord('esc'):
#      24                 break
#      27 cap.release()
#
# TypeError: ord() expected a character, but string of length 3 found
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# 동영상 저장 -> 현재시간, ms, s

from datetime import datetime
import cv2
import numpy as np
#pynput -> 마우스 관련된 핸들링 하지만 cv2에도 내장되어 있음

def mouseHandler(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        print(event, x, y)
        print(datetime.today().second)
        filename = str(datetime.today()) + ".jpg" #file name엔 :이 들어갈 수 없다
        filename = filename.replace(":", "_")
        cv2.imwrite(filename, img)
    
cv2.namedWindow("Camera")
cv2.setMouseCallback("Camera", mouseHandler)

cap = cv2.VideoCapture(0, cv2.CAP_DSHOW)
if cap.isOpened():  
    cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
    cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)

    delay = 33
    while True:
        ret, img = cap.read()
        if ret:
            cv2.imshow("Camera", img)
            if cv2.waitKey(delay) & 0xFF == 27:
                print("ESC is break")  
                break

            
cap.release()
cv2.destroyAllWindows()
# Out:
# 1 715 413
# 1
# ESC is break

# %%
# 동영상 저장 -> 현재시간, ms, s

from datetime import datetime
import cv2
import numpy as np
#pynput -> 마우스 관련된 핸들링 하지만 cv2에도 내장되어 있음

def mouseHandler(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        print(event, x, y)

        filename = str(datetime.today()) + ".jpg" #file name엔 :이 들어갈 수 없다
        filename = filename.replace(":", "_")
        cv2.imwrite(filename, gray_img)
    
cv2.namedWindow("Camera")
cv2.setMouseCallback("Camera", mouseHandler)

cap = cv2.VideoCapture(0, cv2.CAP_DSHOW)
if cap.isOpened():  
    cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
    cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)

    delay = 33
    while True:
        ret, img = cap.read()
        gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        if ret:
            cv2.imshow("Camera", gray_img)
            if cv2.waitKey(delay) & 0xFF == 27:
                print("ESC is break")  
                break
            
cap.release()
cv2.destroyAllWindows()
# Out:
# 1 183 326
# ESC is break

# %%
import cv2
import numpy as np
image = np.full((500, 500, 3), 255, np.uint8)

while(True):
    cv2.imshow("Key Test", image)
    key = cv2.waitKey(0)
    print(f'Code : {key}, Char : {chr(key)}')
    if key & 0xff == 27:
        break
    
cv2.destroyAllWindows()
# Out:
# Code : 104, Char : h
# Code : 101, Char : e
# Code : 108, Char : l
# Code : 108, Char : l
# Code : 111, Char : o
# Code : 27, Char :

# %%
# 이미지 처리 하면서 트랙바 cv.createTrackbar
import cv2
import numpy as np

img = np.zeros((500, 500, 3), np.uint8)
def nothing(x):
    pass

cv2.namedWindow('image')
cv2.createTrackbar('Red', 'image', 0, 255, nothing)
cv2.createTrackbar('Green', 'image', 0, 255, nothing)
cv2.createTrackbar('Blue', 'image', 0, 255, nothing)
cv2.createTrackbar('0 or 1', 'image', 0, 1, nothing)

while(True):
    cv2.imshow('image', img)
    key = cv2.waitKey(1) & 0xff
    if key == 27:
        break
    
    r = cv2.getTrackbarPos('Red', 'image')
    g = cv2.getTrackbarPos('Green', 'image')
    b = cv2.getTrackbarPos('Blue', 'image')
    s = cv2.getTrackbarPos('0 or 1', 'image')
    
    if s == 0:
        img[:] = 0
    else:
        img[:] = [b, g, r]

cv2.destroyAllWindows()

# %%
#flag
cv2.EVENT_LBUTTONUP #1 
cv2.EVENT_RBUTTONUP #2 
cv2.EVENT_MBUTTONUP #4
cv2.EVENT_FLAG_CTRLKEY #8
cv2.EVENT_FLAG_SHIFTKEY #16
cv2.EVENT_FLAG_ALTKEY #32

# %%
# 이미지 처리 하면서 트랙바 cv.createTrackbar
import cv2
import numpy as np

img = np.zeros((500, 500, 3), np.uint8)
cv2.namedWindow('image')

def set_background(x):
    global img
    r = cv2.getTrackbarPos('Red', 'image')
    g = cv2.getTrackbarPos('Green', 'image')
    b = cv2.getTrackbarPos('Blue', 'image')
    s = cv2.getTrackbarPos('0 or 1', 'image')
    
    if s == 0:
        img[:] = 0
    else:
        img[:] = [b, g, r]

cv2.createTrackbar('Red', 'image', 0, 255, set_background)
cv2.createTrackbar('Green', 'image', 0, 255, set_background)
cv2.createTrackbar('Blue', 'image', 0, 255, set_background)
cv2.createTrackbar('0 or 1', 'image', 0, 1, set_background)

while(True):
    cv2.imshow('image', img)
    key = cv2.waitKey(1) & 0xff
    if key == 27:
        break

cv2.destroyAllWindows()

# %%
#도형 선, 사각형, 원, 호, 타원, 다각형, 문자열 
import cv2
import numpy as np

img = np.full((500, 500, 3), 255, dtype = np.uint8)

cv2.line(img, (50, 10), (200, 10), (255, 0, 0), 1)
cv2.line(img, (50, 10 + 50), (200, 10 + 50), (0, 255, 0), 2)
cv2.line(img, (50, 110), (200, 110), (0, 0, 255), 3)
cv2.line(img, (50, 160), (200, 160), (225, 219, 244), 4)
cv2.line(img, (50, 210), (200, 210), (207, 196, 255), 5)

cv2.imshow('Line', img)
cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
#도형 선, 사각형, 원, 호, 타원, 다각형, 문자열 
import cv2
import numpy as np

img = np.full((500, 500, 3), 255, dtype = np.uint8)

cv2.rectangle(img, (50, 10), (100, 60), (255, 0, 0), 1)
cv2.rectangle(img, (50, 70), (100, 120), (0, 255, 0), 2)
cv2.rectangle(img, (50, 130), (100, 180), (0, 0, 255), 3)
cv2.rectangle(img, (50, 190), (100, 240), (225, 219, 244), 4)
cv2.rectangle(img, (50, 250), (100, 300), (207, 196, 255), 5)

cv2.imshow('Rectangle', img)
cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
#도형 선, 사각형, 원, 호, 타원, 다각형, 문자열 
import cv2
import numpy as np

img = np.full((500, 500, 3), 255, dtype = np.uint8)

cv2.circle(img, (50, 50), 50, (255, 0, 0), 1)
cv2.circle(img, (100, 100), 50, (0, 255, 0), 2)
cv2.circle(img, (150, 150), 50, (0, 0, 255), 3)
cv2.circle(img, (200, 200), 50, (225, 219, 244), 4)
cv2.circle(img, (250, 250), 50, (207, 196, 255), 5)

cv2.imshow('Circle', img)
cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
#도형 선, 사각형, 원, 호, 타원, 다각형, 문자열 
import cv2
import numpy as np

img = np.full((500, 500, 3), 255, dtype = np.uint8)

cv2.ellipse(img, (50, 50), (50, 20), -30, 0, 360, (255, 0, 0), 1)
cv2.ellipse(img, (100, 100), (50, 20), 0, 0, 360, (0, 255, 0), 2)
cv2.ellipse(img, (150, 150), (50, 20), 60, 0, 360, (0, 0, 255), 3)
cv2.ellipse(img, (200, 200), (50, 20), -90, 0, 360, (225, 219, 244), 4)
cv2.ellipse(img, (250, 250), (50, 20), 180, 0, 360, (207, 196, 255), 5)

cv2.imshow('Ellipse', img)
cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
#도형 선, 사각형, 원, 호, 타원, 다각형, 문자열 
import cv2
import numpy as np

img = np.full((500, 500, 3), 255, dtype = np.uint8)

cv2.ellipse(img, (100, 100), (100, 50), -60, 0, 180, (209, 178, 255), -1)
cv2.ellipse(img, (100, 100), (100, 50), 120, 0, 180, (207, 196, 255), -1)

cv2.imshow('Ellipse', img)
cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
#도형 선, 사각형, 원, 호, 타원, 다각형, 문자열 
import cv2
import numpy as np

img = np.full((500, 500, 3), 255, dtype = np.uint8)

points = np.array([[50, 50],
                   [100, 100],
                   [70, 120],
                   [60, 200],
                   [30, 180]], 
                   dtype = np.int32)

cv2.polylines(img, [points], False, (209, 178, 255), 5)

cv2.imshow('PolyLines', img)
cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
#도형 선, 사각형, 원, 호, 타원, 다각형, 문자열 
import cv2
import numpy as np

img = np.full((500, 500, 3), 255, dtype = np.uint8)

cv2.putText(img, "Hello OpenCV!!", (50, 50), cv2.FONT_ITALIC, 1.5, (209, 178, 255))
cv2.putText(img, "Hello World!!", (50, 150), cv2.FONT_HERSHEY_COMPLEX, 2.5, (207, 196, 255))
cv2.putText(img, "Hello Python!!", (50, 250), cv2.FONT_HERSHEY_SCRIPT_COMPLEX, 3.5, (209, 178, 255))

cv2.imshow('PutText', img)
cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
#multiline, polyline 가운데는 빨간색
import cv2
import numpy as np

img = np.full((500, 500, 3), 255, dtype = np.uint8)

radius = 250
n = 5
center = (250, 250)
pentagon = []

for i in range(n):
    angle = 360 / n
    angle1 = (360 / n) * i - 90
     # 현재 꼭지점의 좌표 계산
    x = int(center[0] + radius * np.cos(np.radians(angle1)))
    y = int(center[1] + radius * np.sin(np.radians(angle1)))
    pentagon.append((x, y))

    # 다음 꼭지점의 좌표 계산
    next_x = int(center[0] + radius * np.cos(np.radians(angle1 + angle)))
    next_y = int(center[1] + radius * np.sin(np.radians(angle1 + angle)))

cv2.circle(img, (250, 250), 250, (209, 178, 255), 3)

# 5각형의 꼭짓점을 이어서 별 모양을 만들기
star = []
for i in range(5):
    star.append(pentagon[i])
    star.append(pentagon[(i + 2) % 5])  # 현재 꼭짓점과 다음 꼭짓점을 이음.

cv2.polylines(img, [np.array(star)], True, (207, 196, 255), 2)

cv2.imshow('Star', img)
cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import math
from datetime import datetime

img = np.full((500, 500, 3), 255, dtype=np.uint8)
radius = 250
cv2.circle(img, (250, 250), 250, (255, 235, 236), -3)
 
def update_clock(img):
    # 현재 시간 가져오기
    now = datetime.now()
    hour = now.hour
    minute = now.minute
    second = now.second
    
    # 시침, 분침, 초침 그리기
    center = (250, 250)
    hour_length = 150
    minute_length = 200
    second_length = 200
    
    # 시침 그리기
    hour_angle = ((hour % 12) * 30 + (minute / 60) * 30 - 90)
    hour_x = int(center[0] + hour_length * np.cos(np.radians(hour_angle)))
    hour_y = int(center[1] + hour_length * np.sin(np.radians(hour_angle)))
    cv2.line(img, center, (hour_x, hour_y), (255, 178, 181), 5)
    
    # 분침 그리기
    minute_angle = (minute * 6 - 90)
    minute_x = int(center[0] + minute_length * np.cos(np.radians(minute_angle)))
    minute_y = int(center[1] + minute_length * np.sin(np.radians(minute_angle)))
    cv2.line(img, center, (minute_x, minute_y), (72, 255, 250), 3)
    
    # 초침 그리기
    second_angle = (second * 6 - 90)
    second_x = int(center[0] + second_length * np.cos(np.radians(second_angle)))
    second_y = int(center[1] + second_length * np.sin(np.radians(second_angle)))
    cv2.line(img, center, (second_x, second_y), (92,229,188), 1)
    
    # 시계에 숫자 표시하기
    font = cv2.FONT_HERSHEY_SIMPLEX
    font_scale = 1
    font_thickness = 2
    for i in range(1, 13):
        angle = np.radians(i * 30 - 90)
        x = int(center[0] + 220 * np.cos(angle))  # 내부 반지름보다 작은 값으로 조정
        y = int(center[1] + 220 * np.sin(angle))  # 내부 반지름보다 작은 값으로 조정
        cv2.putText(img, str(i), (x, y), font, font_scale, (166, 97, 243), font_thickness, cv2.LINE_AA)

    
    # 업데이트된 시계 이미지 반환
    return img

while True:
    # 시계 이미지 업데이트
    updated_img = update_clock(np.copy(img))
    
    # 시계 이미지 표시
    cv2.imshow('Clock', updated_img)
    
    # 키 입력 대기 (1000ms 동안)
    key = cv2.waitKey(1000)
    
    # 'esc' 키를 누르면 종료
    if key == 27:
        break

cv2.destroyAllWindows()
